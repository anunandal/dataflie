# %%
import pandas as anu

# %%
var1 = anu.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/Employees.csv")

# %%
var1.head()
# Out:
#                     NAME                 JOB TITLE       DEPARTMENT  \
# 0        AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1      AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2    AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3    ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4  ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
#
#   EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# 0              $81000.00                               $73862.00
# 1              $74628.00                               $74628.00
# 2              $77280.00                               $70174.00
# 3              $96276.00                               $96276.00
# 4              $84032.00                               $76627.00

# %%
var2 = anu.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/Restaurant_Reviews.tsv", sep='\t')

# %%
var2.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
var2
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
var3 = anu.read_csv(r"C:\Users\admin\Downloads\Paytm_Statement_financial_year_18_19_7982443901.csv")

# %%
var3.head()
# Out:
#                   Date           Activity  \
# 0  13/10/2018 19:30:28     Paid for order
# 1  13/10/2018 19:30:27    Added to wallet
# 2  13/10/2018 19:23:16     Paid for order
# 3  13/10/2018 19:20:56     Paid for order
# 4     12/10/2018 20:47  Cashback received
#
#                     Transaction Details  Wallet Txn ID  Debit  Credit  \
# 0            Order #SM_4490A4788230883C    20957629728  180.0     NaN
# 1               Paytm Order #6272562213    20957629594    NaN   177.0
# 2  Arun dairy Order #201810131923150010    20957488176   10.0     NaN
# 3            Order #SM_94DD73887F1122CD    20957442838   15.0     NaN
# 4   Paytm Order #TPT5_1stTxn_11Oct_3323    20942295631    NaN     5.0
#
#    Transaction Breakup   Status
# 0                  NaN  SUCCESS
# 1                  NaN  SUCCESS
# 2                  NaN  SUCCESS
# 3                  NaN  SUCCESS
# 4                  NaN  SUCCESS

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin'

# %%
var5 = anu.read_excel("openSAP_sac1_Sales_Analysis.xlsx")

# %%
var5
# Out:
#       Order ID       Date Sales Agent Last Name Sales Agent First Name  \
# 0         2040 2019-05-29               Klassen                  Marc
# 1         3281 2019-05-29                   Pan                Oliver
# 2         3934 2019-05-29                 Pinto                 Brain
# 3         2975 2019-05-29                Narula                  Tommy
# 4         3567 2019-05-29                Petrie                 Maddy
# ...        ...        ...                   ...                    ...
# 2508      2617 2017-06-29                Gibson                  Ashok
# 2509      3588 2017-06-29                   Gao                Carlos
# 2510      3689 2017-06-29                    Yu                 James
# 2511      4362 2017-06-29               Laforge                  Eric
# 2512      3967 2017-06-29             Schilling               Michael
#
#               Customer Customer Segment              Country   Latitude  \
# ...

# %%
print (var1)
# Out:
#                         NAME                 JOB TITLE       DEPARTMENT  \
# 0            AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1          AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
# ...                      ...                       ...              ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER           POLICE
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER      WATER MGMNT
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER           POLICE
# 34216        ZYSKO,  RICHARD                LIEUTENANT             FIRE
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST             DoIT
#
#       EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# ...
